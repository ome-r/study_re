# %%
import pickle
import pandas as pd
from datetime import datetime
import pytz

attendance = pd.DataFrame()

current_attend = pd.DataFrame.from_dict([{
            'date' : datetime.now(pytz.timezone("Asia/Seoul")),
            'name' : '황성연',
            'id' : '20130294',
            # 'seat' : '70',
            'ip' : '10.221.31.253',
            'mac' : 'a0:78:17:7a:df:99',
            'proxy' : None, 
            # 'memo' : 'test'
        }])

# save to pickle
attendance = pd.concat([attendance, current_attend])
with open('static/attendance.pkl', 'wb') as f:
    pickle.dump(attendance, f)

# %%
import pickle
with open('static/attendance.pkl', 'rb') as f:
    attendance = pickle.load(f)
    
attendance
# Out:
#                               date name        id seat             ip  \
# 0 2024-07-08 14:57:22.936682+09:00  황성연  20130294   70  10.221.31.253
#
#                  mac proxy  memo
# 0  a0:78:17:7a:df:99  None  test

# %%
column = 'id'
name = '2019310006'
name2 = '2021315766'
a = pd.concat([attendance[attendance[column] == name], attendance[attendance[column] == name2]]).groupby(['ip']).sum()
# 10.221.31.37
# 10.221.31.42	
# 10.221.31.140
# Out:
# /var/folders/p4/l6qy0qkd2jd9ptr7xxhfl6cc0000gn/T/ipykernel_1137/206921778.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a = pd.concat([attendance[attendance[column] == name], attendance[attendance[column] == name2]]).groupby(['ip']).sum()

# %%
column = 'ip'
name = '10.221.31.37'
name1 = '10.221.31.42'
name2 = '10.221.31.140'
pd.concat([attendance[attendance[column] == name], attendance[attendance[column] == name1], attendance[attendance[column] == name2]]).sort_values('date')
# Out:
#                                 date name          id seat             ip  \
# 7   2023-08-15 09:04:13.669201+09:00  이시훈  2022310043    8   10.221.31.42
# 106 2023-08-15 14:01:59.609107+09:00       2021315766    0  10.221.31.140
# 107 2023-08-15 14:02:02.737556+09:00       2021315766    0  10.221.31.140
# 108 2023-08-15 14:02:05.897527+09:00       2021315766    0  10.221.31.140
# 129 2023-08-15 17:52:47.494127+09:00       2021315766    0  10.221.31.140
# 149 2023-08-15 17:53:06.129011+09:00       2019310006    0  10.221.31.140
# 243 2023-08-16 13:27:52.172053+09:00       2021315766    0   10.221.31.42
# 244 2023-08-16 13:28:45.589325+09:00       2019310006    0   10.221.31.42
# 284 2023-08-16 17:02:15.985160+09:00       2021315766    0   10.221.31.37
# 285 2023-08-16 17:02:17.928439+09:00       2019310006    0   10.221.31.37
# 288 2023-08-16 17:04:31.972896+09:00       2021315766    0   10.221.31.37
# 319 2023-08-16 17:48:17.184145+09:00       2021315766    0   10.221.31.37
#
# ...

# %%
a['id']
# Out:
# ip
# 10.221.31.134                                 20213157662021315766
# 10.221.31.140    2019310006202131576620213157662021315766202131...
# 10.221.31.187    2019310006201931000620193100062019310006201931...
# 10.221.31.236                                           2021315766
# 10.221.31.37              2019310006202131576620213157662021315766
# 10.221.31.42                                  20193100062021315766
# 10.221.31.86                                  20213157662021315766
# 10.221.32.13                        201931000620193100062019310006
# 10.221.32.45                                            2019310006
# 10.221.32.59     2021315766202131576620213157662021315766202131...
# 10.221.32.97                                            2021315766
# Name: id, dtype: object

# %%
for row in a['id']:
    print(row)
# Out:
# 20213157662021315766
# 20193100062021315766202131576620213157662021315766
# 20193100062019310006201931000620193100062019310006
# 2021315766
# 2019310006202131576620213157662021315766
# 20193100062021315766
# 20213157662021315766
# 201931000620193100062019310006
# 2019310006
# 202131576620213157662021315766202131576620213157662021315766
# 2021315766

# %%
import pandas as pd

column = 'date'
date = '2023-08-18 12:00:00'
date2 = '2023-08-18 14:00:00'
attendance.loc[attendance["date"].between(date, date2)]
# Out:
#                                 date name          id seat             ip  \
# 533 2023-08-18 12:56:14.511353+09:00       2021315609    0   10.221.31.85
# 534 2023-08-18 13:00:35.797421+09:00       2019311736    0  10.221.32.129
# 535 2023-08-18 13:01:02.252085+09:00       2022312589    0  10.221.31.198
# 536 2023-08-18 13:01:14.412090+09:00       2021315775    0   10.221.31.36
# 537 2023-08-18 13:01:16.589093+09:00       2021314796    0  10.221.32.131
# 538 2023-08-18 13:01:18.635481+09:00       2019311264    0  10.221.32.129
# 539 2023-08-18 13:01:32.679212+09:00       2021311394    0  10.221.32.162
# 540 2023-08-18 13:01:34.642154+09:00       2019313248    0   10.221.32.22
# 541 2023-08-18 13:02:36.157866+09:00       2019312576    0  10.221.31.188
# 542 2023-08-18 13:02:45.816451+09:00       2019310896    0  10.221.31.115
# 543 2023-08-18 13:05:45.884954+09:00       2018313418    0  10.221.31.105
# 544 2023-08-18 13:05:46.964057+09:00       2018313418    0  10.221.31.105
# ...

# %%
column = 'ip'
name = '10.221.32*'
attendance[attendance[column] == name]
# Out:
# Empty DataFrame
# Columns: [date, name, id, seat, ip, mac, proxy, memo]
# Index: []

# %%
# 학번이랑 연결

# 제일 마지막 것으로 연결

# 중복된 아이피인데 학번이 다른 것 확인

# %%
# id, 이름, 9, 10, 11, 1, 2, 3, 4, 5 표 생성
# 엑셀 가져와서 부분 삭제하고 데이터 프레임으로 만들기
import pandas as pd

attend_excel = pd.read_excel('/Users/jeonminjeong/Downloads/ardino/skku/attend_list.xlsx')
attend_excel
# Out:
#       번호            학번   성명         소속  8월     일  Unnamed: 5  Unnamed: 6  \
# 0    NaN           NaN  NaN        NaN       9.0        10.0        11.0
# 1    1.0  2.023313e+09  강윤석  반도체시스템공학과       NaN         NaN         NaN
# 2    2.0  2.021315e+09   강준    전자전기공학부       NaN         NaN         NaN
# 3    3.0  2.018314e+09  강준구    전자전기공학부       NaN         NaN         NaN
# 4    4.0  2.018314e+09  강태우    전자전기공학부       NaN         NaN         NaN
# ..   ...           ...  ...        ...       ...         ...         ...
# 64  64.0  2.019311e+09  하동현    전자전기공학부       NaN         NaN         NaN
# 65  65.0  2.021316e+09  한주희    전자전기공학부       NaN         NaN         NaN
# 66  66.0  2.019314e+09  허형무    전자전기공학부       NaN         NaN         NaN
# 67  67.0  2.019314e+09  홍승범    전자전기공학부       NaN         NaN         NaN
# 68  68.0  2.019313e+09  황영석    전자전기공학부       NaN         NaN         NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# ...

# %%
# 시간 내에 열을 돌아가면서
column = 'date'
date = '2023-08-18 17:00:00'
date2 = '2023-08-18 18:00:00'
current_attendee = attendance.loc[attendance["date"].between(date, date2)]


# 학번이랑 일치하는 것

# 지정한 컬럼에 동그라미 표시하기
time_area = {
    0: ['8월     일', 'Unnamed: 5', 'Unnamed: 6'],
    1: ['Unnamed: 7', 'Unnamed: 8'],
    2: ['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
}

time_area2 = {
    9: [4, 5, 6],
    1: [7, 8],
    5: [9, 10, 11]
}

# %%
# 아이피가 같은데 학번이 다른 것 확인
len(current_attendee.groupby(['id', 'ip']).count()), \
len(current_attendee.groupby(['id']).count()), \
len(current_attendee.groupby(['ip']).count())
# Out:
# (17, 17, 16)

# %%
current_attendee.groupby(['ip']).sum()
# Out:
# /var/folders/p4/l6qy0qkd2jd9ptr7xxhfl6cc0000gn/T/ipykernel_1137/3948848916.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   current_attendee.groupby(['ip']).sum()
#               name                                                 id    seat  \
# ip
# 10.221.31.105                                    20183134182018313418      00
# 10.221.31.115                                              2019310896       0
# 10.221.31.118                                              2023312935       0
# 10.221.31.122                          202331411120233141112023314111     000
# 10.221.31.13        2021315591202131559120213155912021315591202131...  000000
# 10.221.31.143                                              2019311294       0
# ...

# %%
current_attendee
# 10.221.31.151 
# 10.221.31.42
# 10.221.32.113
# 10.221.32.199 정승연 안재준
# Out:
#                                 date name          id seat             ip  \
# 533 2023-08-18 12:56:14.511353+09:00       2021315609    0   10.221.31.85
# 534 2023-08-18 13:00:35.797421+09:00       2019311736    0  10.221.32.129
# 535 2023-08-18 13:01:02.252085+09:00       2022312589    0  10.221.31.198
# 536 2023-08-18 13:01:14.412090+09:00       2021315775    0   10.221.31.36
# 537 2023-08-18 13:01:16.589093+09:00       2021314796    0  10.221.32.131
# 538 2023-08-18 13:01:18.635481+09:00       2019311264    0  10.221.32.129
# 539 2023-08-18 13:01:32.679212+09:00       2021311394    0  10.221.32.162
# 540 2023-08-18 13:01:34.642154+09:00       2019313248    0   10.221.32.22
# 541 2023-08-18 13:02:36.157866+09:00       2019312576    0  10.221.31.188
# 542 2023-08-18 13:02:45.816451+09:00       2019310896    0  10.221.31.115
# 543 2023-08-18 13:05:45.884954+09:00       2018313418    0  10.221.31.105
# 544 2023-08-18 13:05:46.964057+09:00       2018313418    0  10.221.31.105
# ...

# %%
attend_ids = current_attendee.groupby(['id']).sum().index.to_list()
# Out:
# /var/folders/p4/l6qy0qkd2jd9ptr7xxhfl6cc0000gn/T/ipykernel_1137/2079982658.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   attend_ids = current_attendee.groupby(['id']).sum().index.to_list()

# %%
attend_excel
# Out:
#       번호            학번   성명         소속  8월     일  Unnamed: 5  Unnamed: 6  \
# 0    NaN           NaN  NaN        NaN       9.0        10.0        11.0
# 1    1.0  2.023313e+09  강윤석  반도체시스템공학과       NaN         NaN         NaN
# 2    2.0  2.021315e+09   강준    전자전기공학부       NaN         NaN         NaN
# 3    3.0  2.018314e+09  강준구    전자전기공학부       NaN         NaN         NaN
# 4    4.0  2.018314e+09  강태우    전자전기공학부       NaN         NaN         NaN
# ..   ...           ...  ...        ...       ...         ...         ...
# 64  64.0  2.019311e+09  하동현    전자전기공학부       NaN         NaN         NaN
# 65  65.0  2.021316e+09  한주희    전자전기공학부       NaN         NaN         NaN
# 66  66.0  2.019314e+09  허형무    전자전기공학부       NaN         NaN         NaN
# 67  67.0  2.019314e+09  홍승범    전자전기공학부       NaN         NaN         NaN
# 68  68.0  2.019313e+09  황영석    전자전기공학부       NaN         NaN         NaN
#
#    Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# ...

# %%
for idx, id in enumerate(attend_ids):
    for col in time_area[2]:
        attend_excel.loc[attend_excel['학번'] == int(attend_ids[idx]), col] = 'O'

# %%
attend_excel.to_excel('/Users/jeonminjeong/Downloads/ardino/skku/attend_list_17.xlsx')

# %%
attend_excel[attend_excel['학번'] == int('2019311264')]
# Out:
#       번호            학번  성명       소속  8월     일  Unnamed: 5  Unnamed: 6  \
# 59  59.0  2.019311e+09  정훈  전자전기공학부       NaN         NaN         NaN
#
#    Unnamed: 7 Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 59        NaN        NaN         NaN          NaN          NaN

# %%
attend_excel
# Out:
#       번호            학번   성명         소속  8월     일 Unnamed: 5 Unnamed: 6  \
# 0    NaN           NaN  NaN        NaN       9.0       10.0       11.0
# 1    1.0  2.023313e+09  강윤석  반도체시스템공학과       NaN        NaN        NaN
# 2    2.0  2.021315e+09   강준    전자전기공학부       NaN        NaN        NaN
# 3    3.0  2.018314e+09  강준구    전자전기공학부       NaN        NaN        NaN
# 4    4.0  2.018314e+09  강태우    전자전기공학부       NaN        NaN        NaN
# ..   ...           ...  ...        ...       ...        ...        ...
# 64  64.0  2.019311e+09  하동현    전자전기공학부       NaN        NaN        NaN
# 65  65.0  2.021316e+09  한주희    전자전기공학부       NaN        NaN        NaN
# 66  66.0  2.019314e+09  허형무    전자전기공학부       NaN        NaN        NaN
# 67  67.0  2.019314e+09  홍승범    전자전기공학부       NaN        NaN        NaN
# 68  68.0  2.019313e+09  황영석    전자전기공학부       NaN        NaN        NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11 8월 일
# ...

# %%
# attendance[attendance['ip'] != '' 
           
# condition = attendance['ip'].str.startswith('10.221.31.')
attendance[~attendance.ip.str.startswith(('10.221.31.'))]
# Out:
#                                 date name          id seat             ip  \
# 1   2023-08-15 08:49:25.703021+09:00  전민정      000000   70      127.0.0.1
# 10  2023-08-15 09:04:29.711426+09:00  이준혁  2019311736   41  10.221.32.129
# 12  2023-08-15 09:04:37.466002+09:00  전승민  2021315591   48  10.221.32.113
# 18  2023-08-15 09:04:59.037395+09:00  김준환  2019310435   17  10.221.32.144
# 26  2023-08-15 09:05:51.731946+09:00  고한음  2018310267    5   10.221.32.91
# ..                               ...  ...         ...  ...            ...
# 566 2023-08-18 13:20:33.933527+09:00       2019310006    0   10.221.32.45
# 567 2023-08-18 13:20:34.754673+09:00       2018310267    0  10.221.32.125
# 568 2023-08-18 13:26:51.645430+09:00       2019313101    0   10.221.32.69
# 569 2023-08-18 13:27:21.501073+09:00       2021315766    0   10.221.32.97
# 570 2023-08-18 13:31:38.658573+09:00       2020315770    0  10.221.32.126
#
#       mac proxy memo
# 1    None  None  NaN
# 10   None  None
# 12   None  None
# ...

# %%
attendance[attendance['id'] == '2023314111']
# Out:
#                                 date name          id seat             ip  \
# 99  2023-08-15 13:07:51.769073+09:00       2023314111    0   10.221.31.41
# 101 2023-08-15 13:08:16.623355+09:00       2023314111    0   10.221.31.41
# 140 2023-08-15 17:52:58.969193+09:00       2023314111    0   10.221.31.41
# 144 2023-08-15 17:53:02.505154+09:00       2023314111    0   10.221.31.41
# 145 2023-08-15 17:53:03.387615+09:00       2023314111    0   10.221.31.41
# 147 2023-08-15 17:53:04.231328+09:00       2023314111    0   10.221.31.41
# 162 2023-08-16 09:01:49.310850+09:00       2023314111    0   10.221.31.27
# 163 2023-08-16 09:01:51.996209+09:00       2023314111    0   10.221.31.27
# 164 2023-08-16 09:01:52.689160+09:00       2023314111    0   10.221.31.27
# 165 2023-08-16 09:01:55.454488+09:00       2023314111    0   10.221.31.27
# 166 2023-08-16 09:02:02.727943+09:00       2023314111    0   10.221.31.27
# 220 2023-08-16 13:06:17.155266+09:00       2023314111    0  10.221.31.151
# ...
